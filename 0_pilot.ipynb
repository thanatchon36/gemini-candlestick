# %%
print('OK ')
# Out:
# OK

# %%
#Default
import pandas as pd
pd.options.display.float_format = '{:,}'.format
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
def reset(df):
    cols = df.columns
    return df.reset_index()[cols]
def print_counts(df):
    cols = df.columns
    for each in cols:
        print(each)
        print(df[each].value_counts())
        print('______________________________________')
# ~
#Default Ending

from plotly.subplots import make_subplots
from plotly.graph_objects import Scatter
from plotly.io import to_image
from itertools import accumulate 

import datetime
import time

from tqdm import tqdm
import numpy as np


import json

from autotrade import autotrade
import google.generativeai as genai


def human_format(num):
    magnitude = 0
    while abs(num) >= 1000:
        magnitude += 1
        num /= 1000.0
    # add more suffixes if you need them
    return '%.0f%s' % (num, ['', 'K', 'M', 'G', 'T', 'P'][magnitude])

def add(a, b):
    return a + b

def get_color_list(values):
    # Define dark and light shades of green and red
    dark_green = '#26A69A'
    light_green = '#B2DFDB'
    light_red = '#FFCDD2'
    dark_red = '#FF5252'
    colors = []
    previous_value = values[0]
    for value in values:
        if value < 0:
            if value < previous_value:
                colors.append(dark_red)
            else:
                colors.append(light_red)
        elif value > 0:
            if value > previous_value:
                colors.append(dark_green)
            else:
                colors.append(light_green)
        else:
            colors.append(light_green)  # Adjust for zero values as needed
        previous_value = value
    return colors

# Function to format y-axis labels
def millions_formatter(x, pos):
    num = x
    magnitude = 0
    while abs(num) >= 1000:
        magnitude += 1
        num /= 1000.0
    # add more suffixes if you need them
    return '%.0f%s' % (num, ['', 'K', 'M', 'G', 'T', 'P'][magnitude])
def comma_formatter(x, pos):
    return "{:,}".format(x)
def comma_formatter_2(x, pos):
    return "{:,.2f}".format(x)
def title_formatter(x):
    return "{:.2f}".format(x)

import talib
from plotly.tools import mpl_to_plotly
import matplotlib
matplotlib.use('Agg')

import matplotlib.pyplot as plt
plt.rc('figure', figsize = (15, 12), dpi = 300)
from mplfinance.original_flavor import candlestick_ohlc
import matplotlib.dates as mdates
from matplotlib.ticker import FuncFormatter
from matplotlib.lines import Line2D

from autotrade import *

def get_date_month_text(date_str):
    date_obj = datetime.datetime.strptime(date_str, "%Y-%m-%d")
    return date_obj.strftime("%d %b")

# from IPython.display import display, HTML
# display(HTML("<style>.container { width:100% !important; }</style>"))

print('OK !')
# Out:
# /var/folders/v6/n3wvvznj569b16762k0t9ywc0000gn/T/ipykernel_9275/394143568.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# OK !

# %%
self = autotrade(   binance_api_key = "",
                    binance_api_secret = "",
                    line_api_key = "line_api_key",
                    ws_name = "ws_name",
                    freq_interval = "1d",
)
self.temp_leverage_no = 1
self.risk_ratio = 0.95
self.batchOrders_no = 1

self.gemini_key = "AIzaSyCY2krWzRCAMU9n4BP4KAeQgDeQ2cM9NgI"
self.line_api_key = "j4dam1oWU2EhslISH1HBig71OvYUIfDbG8U4ufMdvc5"
# self.gemini_key = "AIzaSyDZKy-_yHEtMqmVF-62t7Q7n5r_Ca0HRCU"

self.depth_limit_no = 1000
# self.temperature = 0.65
self.temperature = 1.0

self.symbol = 'BTCUSDT'
# self.model = 'gemini-1.5-pro-latest'
self.model = 'gemini-1.5-flash-latest'

timeframe = self.freq_interval

# %%
# self.update_next_current_time_interval()

# %%
# wait_entry_sec = self.next_current_time_interval_df['next_entry_sec'].values[0]

# %%
# (wait_entry_sec ) / (60*60)

# %%
self.prep_sp100_nasdaq100_dataset()
# Out:
# [*********************100%%**********************]  171 of 171 completed
#
# 4 Failed downloads:
# ['ATVI', 'SPLK', 'SGEN', 'RTN']: Exception('%ticker%: No data found, symbol may be delisted')
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 171/171 [00:03<00:00, 54.65it/s]

# %%
# for each_ticker in tqdm(self.sp100_nasdaq100_df['symbol'].values[:202]):
#     self.ticker = each_ticker
#     self.get_candlestick_image()

# %%
self.ticker = 'GOOGL'
df = self.get_candlestick_data()
self.current_meeting_date
# Out:
# 'May 24, 2024, at 00:00'

# %%
# print(self.get_system_instructions_1())

# %%
# พูดถึง overall picture ของ segment ต่างๆ

# %%
# %time self.get_gemini_response()

# %%
genai.configure(api_key=self.gemini_key)

self.prompt_parts = []
for each_ticker in tqdm(self.ticker_list[:202]):
    self.ticker = each_ticker
    temp_file = genai.upload_file(path=f"data/png/{each_ticker}.png", display_name=f'{self.ticker_company} ({each_ticker}): 1d Candlestick Chart (with Technical Indicators)')
    self.prompt_parts.append(temp_file)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 166/166 [07:38<00:00,  2.76s/it]

# %%
# def get_system_instructions_1(self):
#     self.board_member_no = 10
#     # self.current_meeting_date
#     # self.company_ticker_text
#     # self.company_ticker_list[0]
#     # len(self.company_ticker_list)
#     system_instructions = f"""
#     {self.get_judge_instructions()}

#     **Google Gemini:** The Gemini Candlestick Investment Fund employs a dynamic investment strategy that capitalizes on both market growth and volatility. The Fund strategically allocates capital to a portfolio of core holdings, representing established companies with long-term growth potential, while simultaneously employing tactical opportunities to profit from short-term market fluctuations. This dual approach allows the Fund to navigate market cycles effectively, aiming to maximize returns through both growth investments and market-neutral strategies. This strategy, guided by the collective wisdom of the ten-member Board of Directors, ensures a balanced and diversified approach to investment, seeking to generate consistent and sustainable profitability for its stakeholders. The meeting minutes will primarily focus on the judging round mentioned earlier and aim to maximize the score closely to 65 as much as possible.

#     **Target User Persona:** This application is designed for financial analysts, portfolio managers, and individuals interested in understanding how technical analysis and expert opinions can be integrated to make investment decisions. 

#     **User Needs:**  Users need a clear and concise summary of expert opinions on various stocks and overall market sectors based on technical indicators and market trends. This information aids in making informed investment decisions. 

#     **Meeting Details:**

#     * **Date:** {self.current_meeting_date}
#     * **Time:** 00:00 - 01:00
#     * **Location:** Google Meet

#     **Stock Selection:**

#     The Board of Directors will be analyzing the following {len(self.company_ticker_list)} stocks:

#     {self.company_ticker_text}.

#     **Data:**

#     The Board will have access to hypothetical candlestick charts and technical indicator data (Volume, RSI, MACD, Bollinger Bands, Fibonacci Retracement, Ichimoku Cloud, Stochastic Oscillator, Chaikin Money Flow, On-Balance Volume, and Average True Range) for each of these stocks, reflecting recent market activity. 

#     **Board Members:**

#     The Board of Directors comprises 10 preeminent members merging technical expertise with a deep understanding of market sectors and trends:

#     1. Munehisa Homma, Chairman of the meeting:(assigned to analyze Candlestick Pattern Recognition and provide an opinion)
#     2. John Bollinger (assigned to analyze the BB indicator and provide an opinion)
#     3. Leonardo Pisano Fibonacci (assigned to analyze Fibonacci retracement and provide an opinion)
#     4. Ralph Nelson Elliott, assigned to analyze potential Elliott Wave patterns, utilized Fibonacci ratios (0.786, 0.618, 0.5, 0.382, and 0.236 on Fibonacci retracement charts), RSI, MACD, and Bollinger Bands to determine the extent of wave retracements and projections within the patterns, and to provide an opinion. 
#     5. Goichi Hosoda (assigned to analyze the Ichimoku Cloud and provide an opinion) 
#     6. Joseph Granville (assigned to analyze the Volume and On Balance Volume indicators and provide an opinion)
#     7. Gerald Appel (assigned to analyze the MACD indicator and provide an opinion)
#     8. J. Welles Wilder (assigned to analyze RSI and ATR indicators and provide an opinion)
#     9. George Lane (assigned to analyze the stochastic oscillator indicator and provide an opinion)
#     10. Marc Chaikin (assigned to analyze the Chaikin Money Flow indicator and provide an opinion)

#     **Instructions:**

#     1. **Broad Market Analysis:**
#         * Begin the meeting minutes with a concise analysis of the following sectors:
#         - 'Information Technology'
#         - 'Health Care'
#         - 'Consumer Discretionary'
#         - 'Communication Services'
#         - 'Industrials'
#         - 'Consumer Staples'
#         - 'Utilities'
#         - 'Renewable Energy'
#         - 'Real Estate'
#         - 'Materials'
#         - 'Financials' 
#         *  Synthesize the Board's collective opinion on each sector, including relevant technical indicator observations and potential trends. 
#         *  Utilize a more professional and business-oriented language, incorporating critical analysis that establishes connections among significant sectors.
#         *  Link between sectors in Broad Market Analysis and generate critical thoughts on these links.

#     2. **Discussion:**
#         * Following the broad market analysis, describe a hypothetical discussion flow focusing on specific stock analysis examples.
#         * **Example:** "{self.example_analysis_text}"
#         * Continue creating a narrative for the meeting, incorporating various opinions and disagreements, connecting board member expertise with specific ticker symbols from the list.
#         * Highlight at least one stock from each market sector.

#     3. **Consensus & Action:**

#     * **Market Sentiment:**  
#         * The Board assessed the overall market sentiment for relevant sectors, considering: 
#             * [List specific factors analyzed, e.g., economic indicators, sector trends, investor sentiment surveys].
#         * The Board's interpretation of these factors suggests a [Bullish/Bearish/Neutral] outlook for the near term.
#     * **Fund Position:**

#     **Based on an analysis of market sentiment and identified opportunities, the Board has determined the following strategy:**
#         * **Adopting bullish positions:** To capitalize on potential market growth.
#         * **Executing a bearish strategy:** To take advantage of anticipated market declines.
#         * **Maintaining a neutral stance:** To navigate uncertain market conditions.
#         * **Focusing on specific sectors:** To maximize potential returns.
#         * **Allocating capital proportionally to the Board's confidence in each opportunity.**
#         **The Board will consider a carefully selected number of stocks for potential trading actions, prioritizing those with the highest conviction levels.**
#         **Position sizing will be determined on a case-by-case basis, ensuring that capital is allocated based on the Board's confidence in each opportunity.** 

#     * **Alternative Strategies Considered:**
#         * [Briefly list alternative approaches that were discussed and the rationale for not selecting them at this time. This demonstrates thoroughness.]
#     * **Risk Management:**
#         * The Board acknowledges the inherent risks associated with the chosen strategy and has implemented appropriate measures to mitigate potential losses, such as:
#             * [List risk management techniques, e.g., stop-loss orders, diversification across sectors, hedging strategies, position limits]. 
#     * **Monitoring & Review:**
#         * The Board will actively monitor market conditions and the performance of selected positions.
#         * The Board will reconvene in [timeframe, e.g., one week, two weeks] to review the fund's position and make any necessary adjustments based on evolving market dynamics and new information.

#     4. **Ticker Symbols of Interest:**
#         * Based on the discussion, list a few of the ticker symbols that were highlighted and provide reasons for their attention. These reasons should directly relate to the analysis conducted by the board members.

#     5. **Further Action:**
#         * The Board instructed the Fund's management team to execute the agreed-upon market position and further investigate the highlighted ticker symbols for potential investment actions aligned with the Fund's overall strategy.

#     6. **Meeting Adjourned:** 01:30

#     7. **Approved by:**
#         * Munehisa Homma, Chairman
#     """
#     return system_instructions

# %%
# print(get_system_instructions_3(self))

# %%
sys_prompt = """
'\n        \n        ## JUDGING ROUND\n\n        Sponsor will evaluate each Entrant and their Submission. Your Submission, including Your video and code will be evaluated based on following\xa0judging criteria\xa0(the “Judging Criteria”), weighted equally:\n\n        * Submissions will be evaluated by Google judges who excel in the following five (5) categories as they relate to this challenge: impact, remarkability, creativity, usefulness, and execution. Each criteria will be scored on a scale of 1 (strongly disagree) to 5 (strongly agree). \n\n        The judging criteria is as follows:\n\n        **Category 1: Impact**\n\n        * Is the solution easy and enjoyable to use for everyone, including people with disabilities? (maximum 5 points)\n        * Does this solution have potential to contribute meaningfully to environmental sustainability? (maximum 5 points)\n        * Does this solution have potential to contribute meaningfully to improving people\'s lives? (maximum 5 points)\n\n        **Category 2: Remarkability**\n\n        * Is the submission surprising to those that are well-versed in Large Language Models (“LLM”)? (maximum 5 points)\n        * Is the submission surprising to those that are not well-versed in LLM? (maximum 5 points)\n\n        **Category 3: Creativity**\n\n        * Does the submission differ from existing, well known, applications in functionality? (maximum 5 points)\n        * Does the submission differ from existing, well known, applications in user experience? (maximum 5 points)\n        * Is the submission implemented through the use of creative problem-solving approaches? (maximum 5 points)\n\n        **Category 4: Usefulness**\n\n        * Does the submission include a well-defined target user persona/segmentation? (maximum 5 points)\n        * Does the submission identify how the solution addresses specific user needs? (maximum 5 points)\n        * How well does the solution, as implemented, help users meet these needs? (maximum 5 points)\n\n        **Category 5: Execution**\n\n        * Is the solution well-designed and adhere to software engineering practices? (maximum 5 points)\n        * Is the LLM component of the solution well-designed and adhere to Machine Learning (ML)/LLM best practices? (maximum 5 points)\n\n        **Maximum score: 65**\n\n        *Best Overall Submission will be determined by the Entrant who has the highest score in the combined categories of Impact, Creativity and Usefulness. In the event of a tie, Sponsor will determine the Best Overall Submission Prize. Sponsor’s decision is final and binding.* \n        \n\n        **Google Gemini:** The Gemini Candlestick Investment Fund employs a dynamic investment strategy that capitalizes on both market growth and volatility. The Fund strategically allocates capital to a portfolio of core holdings, representing established companies with long-term growth potential, while simultaneously employing tactical opportunities to profit from short-term market fluctuations. This dual approach allows the Fund to navigate market cycles effectively, aiming to maximize returns through both growth investments and market-neutral strategies. This strategy, guided by the collective wisdom of the ten-member Board of Directors, ensures a balanced and diversified approach to investment, seeking to generate consistent and sustainable profitability for its stakeholders. The meeting minutes will primarily focus on the judging round mentioned earlier and aim to maximize the score closely to 65 as much as possible.\n\n        **Target User Persona:** This application is designed for financial analysts, portfolio managers, and individuals interested in understanding how technical analysis and expert opinions can be integrated to make investment decisions. \n\n        **User Needs:**  Users need a clear and concise summary of expert opinions on various stocks and overall market sectors based on technical indicators and market trends. This information aids in making informed investment decisions. \n\n        **Meeting Details:**\n\n        * **Date:** May 24, 2024, at 00:00\n        * **Time:** 00:00 - 01:00\n        * **Location:** Google Meet\n\n        **Stock Selection:**\n\n        The Board of Directors will be analyzing the following 166 stocks:\n\n        The Goldman Sachs Group Inc. (GS), Broadcom Inc. (AVGO), Intuitive Surgical Inc. (ISRG), Amazon.com Inc. (AMZN), Chevron Corporation (CVX), Verizon Communications Inc. (VZ), Cadence Design Systems Inc. (CDNS), Walmart Inc. (WMT), Fortinet Inc. (FTNT), Walgreens Boots Alliance Inc. (WBA), Medtronic PLC (MDT), McDonald\'s Corporation (MCD), Micron Technology Inc. (MU), American International Group Inc. (AIG), KLA-Tencor Corporation (KLAC), PayPal Holdings Inc. (PYPL), PACCAR Inc (PCAR), The Coca-Cola Company (KO), Align Technology Inc. (ALGN), Okta, Inc. (OKTA), Abbott Laboratories (ABT), AstraZeneca PLC (AZN), General Electric Company (GE), Merck & Co. Inc. (MRK), NetEase Inc. (NTES), Skyworks Solutions Inc. (SWKS), Mondelez International Inc. (MDLZ), eBay Inc. (EBAY), Nike, Inc. (NKE), AT&T Inc (T), MetLife Inc. (MET), American Electric Power Company Inc. (AEP), Illumina Inc. (ILMN), IDEXX Laboratories Inc. (IDXX), Duke Energy Corporation (DUK), Union Pacific Corporation (UNP), Biogen Inc. (BIIB), Monster Beverage Corporation (MNST), Fastenal Company (FAST), Marriott International Inc. (MAR), The Home Depot Inc. (HD), Lowe\'s Companies Inc. (LOW), Capital One Financial Corporation (COF), Emerson Electric Co. (EMR), Synopsys Inc. (SNPS), 3M Company (MMM), DexCom, Inc. (DXCM), Palo Alto Networks, Inc. (PANW), Linde PLC (LIN), Meta Platforms, Inc. (META), CrowdStrike Holdings, Inc. (CRWD), Comcast Corporation (CMCSA), U.S. Bancorp (USB), The Charles Schwab Corporation (SCHW), Costco Wholesale Corporation (COST), Visa Inc. (V), Pinduoduo Inc. (PDD), Altria Group Inc. (MO), NVIDIA Corporation (NVDA), CSX Corporation (CSX), Microchip Technology Inc. (MCHP), Applied Materials Inc. (AMAT), Amgen Inc. (AMGN), Paychex Inc. (PAYX), The Kraft Heinz Company (KHC), United Parcel Service Inc. (UPS), FedEx Corporation (FDX), Philip Morris International Inc. (PM), Xcel Energy Inc. (XEL), Starbucks Corporation (SBUX), Oracle Corporation (ORCL), AbbVie Inc. (ABBV), Sirius XM Holdings Inc. (SIRI), Verisk Analytics Inc. (VRSK), Atlassian Corporation Plc (TEAM), ConocoPhillips (COP), The Boeing Company (BA), DocuSign, Inc. (DOCU), General Dynamics Corporation (GD), Mastercard Inc. (MA), Honeywell International Inc. (HON), Datadog, Inc. (DDOG), The Walt Disney Company (DIS), Colgate-Palmolive Company (CL), Vertex Pharmaceuticals Inc. (VRTX), American Tower Corporation (AMT), Zscaler, Inc. (ZS), American Express Company (AXP), Regeneron Pharmaceuticals Inc. (REGN), Netflix Inc. (NFLX), Advanced Micro Devices Inc. (AMD), Baidu Inc. (BIDU), Copart Inc. (CPRT), Microsoft Corporation (MSFT), Dow Inc. (DOW), Moderna, Inc. (MRNA), Keurig Dr Pepper Inc. (KDP), ASML Holding N.V. (ASML), NextEra Energy Inc. (NEE), Texas Instruments Inc. (TXN), Exxon Mobil Corporation (XOM), Lam Research Corporation (LRCX), Bank of America Corporation (BAC), NXP Semiconductors N.V. (NXPI), Automatic Data Processing Inc. (ADP), Booking Holdings Inc. (BKNG), lululemon athletica inc. (LULU), Berkshire Hathaway Inc. (BRK-B), Cisco Systems Inc. (CSCO), Adobe Inc. (ADBE), Thermo Fisher Scientific Inc. (TMO), Airbnb, Inc. (ABNB), Ford Motor Company (F), Accenture PLC (ACN), VeriSign Inc. (VRSN), UnitedHealth Group Inc. (UNH), Wells Fargo & Company (WFC), Gilead Sciences Inc. (GILD), Citigroup Inc. (C), Intuit Inc. (INTU), Morgan Stanley (MS), JD.com Inc. (JD), salesforce.com Inc. (CRM), Match Group, Inc. (MTCH), Lucid Motors (LCID), Southern Company (SO), Charter Communications Inc. (CHTR), Apple Inc. (AAPL), Pfizer Inc. (PFE), Intel Corporation (INTC), Lockheed Martin Corporation (LMT), Marvell Technology Group Ltd. (MRVL), Qualcomm Inc. (QCOM), Constellation Brands Inc. (STZ), Old Dominion Freight Line, Inc. (ODFL), The Bank of New York Mellon Corporation (BK), Dollar Tree Inc. (DLTR), O\'Reilly Automotive Inc. (ORLY), JPMorgan Chase & Co. (JPM), Alphabet Inc. (GOOGL), General Motors Company (GM), Autodesk Inc. (ADSK), Tesla Inc. (TSLA), Mercado Libre, Inc. (MELI), Danaher Corporation (DHR), Cognizant Technology Solutions Corporation (CTSH), Electronic Arts Inc. (EA), Workday, Inc. (WDAY), The Procter & Gamble Company (PG), BlackRock Inc. (BLK), Target Corporation (TGT), T-Mobile US Inc. (TMUS), Bristol-Myers Squibb Company (BMY), Cintas Corporation (CTAS), CVS Health Corporation (CVS), Johnson & Johnson (JNJ), International Business Machines Corporation (IBM), PepsiCo, Inc. (PEP), Analog Devices Inc. (ADI), Simon Property Group Inc. (SPG), Caterpillar Inc. (CAT), Ross Stores Inc. (ROST), Zoom Video Communications, Inc. (ZM), Eli Lilly and Company (LLY), ANSYS Inc. (ANSS), Exelon Corporation (EXC).\n\n        **Data:**\n\n        The Board will have access to hypothetical candlestick charts and technical indicator data (Volume, RSI, MACD, Bollinger Bands, Fibonacci Retracement, Ichimoku Cloud, Stochastic Oscillator, Chaikin Money Flow, On-Balance Volume, and Average True Range) for each of these stocks, reflecting recent market activity. \n\n        **Board Members:**\n\n        The Board of Directors comprises 10 preeminent members merging technical expertise with a deep understanding of market sectors and trends:\n\n        1. Munehisa Homma, Chairman of the meeting:(assigned to analyze Candlestick Pattern Recognition and provide an opinion)\n        2. John Bollinger (assigned to analyze the BB indicator and provide an opinion)\n        3. Leonardo Pisano Fibonacci (assigned to analyze Fibonacci retracement and provide an opinion)\n        4. Ralph Nelson Elliott, assigned to analyze potential Elliott Wave patterns, utilized Fibonacci ratios (0.786, 0.618, 0.5, 0.382, and 0.236 on Fibonacci retracement charts), RSI, MACD, and Bollinger Bands to determine the extent of wave retracements and projections within the patterns, and to provide an opinion. \n        5. Goichi Hosoda (assigned to analyze the Ichimoku Cloud and provide an opinion) \n        6. Joseph Granville (assigned to analyze the Volume and On Balance Volume indicators and provide an opinion)\n        7. Gerald Appel (assigned to analyze the MACD indicator and provide an opinion)\n        8. J. Welles Wilder (assigned to analyze RSI and ATR indicators and provide an opinion)\n        9. George Lane (assigned to analyze the stochastic oscillator indicator and provide an opinion)\n        10. Marc Chaikin (assigned to analyze the Chaikin Money Flow indicator and provide an opinion)\n\n        **Instructions:**\n\n        1. **Broad Market Analysis:**\n            * Begin the meeting minutes with a concise analysis of the following sectors:\n            - Real Estate\n- Information Technology\n- Communication Services\n- Financials\n- Renewable Energy\n- Industrials\n- Health Care\n- Utilities\n- Consumer Discretionary\n- Materials\n- Consumer Staples\n            *  Synthesize the Board\'s collective opinion on each sector, including relevant technical indicator observations and potential trends. \n            *  Utilize a more professional and business-oriented language, incorporating critical analysis that establishes connections among significant sectors.\n            *  Link between sectors in Broad Market Analysis and generate critical thoughts on these links.\n\n        2. **Discussion:**\n            * Following the broad market analysis, describe a hypothetical discussion flow focusing on specific stock analysis examples.\n            * **Example:** "John Bollinger, reviewing the Bollinger Bands of **Wells Fargo & Company (WFC)**,..."\n            * Continue creating a narrative for the meeting, incorporating various opinions and disagreements, connecting board member expertise with specific ticker symbols from the list.\n            * Highlight at least one stock from each market sector.\n\n        3. **Consensus & Action:**\n\n        * **Market Sentiment:**  \n            * The Board assessed the overall market sentiment for relevant sectors, considering: \n                * [List specific factors analyzed, e.g., economic indicators, sector trends, investor sentiment surveys].\n            * The Board\'s interpretation of these factors suggests a [Bullish/Bearish/Neutral] outlook for the near term.\n        * **Fund Position:**\n\n        **Based on an analysis of market sentiment and identified opportunities, the Board has determined the following strategy:**\n            * **Adopting bullish positions:** To capitalize on potential market growth.\n            * **Executing a bearish strategy:** To take advantage of anticipated market declines.\n            * **Maintaining a neutral stance:** To navigate uncertain market conditions.\n            * **Focusing on specific sectors:** To maximize potential returns.\n            * **Allocating capital proportionally to the Board\'s confidence in each opportunity.**\n            **The Board will consider a carefully selected number of stocks for potential trading actions, prioritizing those with the highest conviction levels.**\n            **Position sizing will be determined on a case-by-case basis, ensuring that capital is allocated based on the Board\'s confidence in each opportunity.** \n\n        * **Alternative Strategies Considered:**\n            * [Briefly list alternative approaches that were discussed and the rationale for not selecting them at this time. This demonstrates thoroughness.]\n        * **Risk Management:**\n            * The Board acknowledges the inherent risks associated with the chosen strategy and has implemented appropriate measures to mitigate potential losses, such as:\n                * [List risk management techniques, e.g., stop-loss orders, diversification across sectors, hedging strategies, position limits]. \n        * **Monitoring & Review:**\n            * The Board will actively monitor market conditions and the performance of selected positions.\n            * The Board will reconvene in [timeframe, e.g., one week, two weeks] to review the fund\'s position and make any necessary adjustments based on evolving market dynamics and new information.\n\n        4. **Ticker Symbols of Interest:**\n            * Based on the discussion, list a few of the ticker symbols that were highlighted and provide reasons for their attention. These reasons should directly relate to the analysis conducted by the board members.\n\n        5. **Further Action:**\n            * The Board instructed the Fund\'s management team to execute the agreed-upon market position and further investigate the highlighted ticker symbols for potential investment actions aligned with the Fund\'s overall strategy.\n\n        6. **Meeting Adjourned:** 01:30\n\n        7. **Approved by:**\n            * Munehisa Homma, Chairman\n        '
"""

# %%
generation_config = {
"temperature": self.temperature,
"top_p": 0.95,
"top_k": 64,
"max_output_tokens": 500000,
"response_mime_type": "text/plain",
}
safety_settings = [
{
    "category": "HARM_CATEGORY_HARASSMENT",
    "threshold": "BLOCK_NONE"
},
{
    "category": "HARM_CATEGORY_HATE_SPEECH",
    "threshold": "BLOCK_NONE"
},
{
    "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
    "threshold": "BLOCK_NONE"
},
{
    "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
    "threshold": "BLOCK_NONE"
},
]

system_instruction_1 = sys_prompt

# system_instruction_1 = self.get_system_instructions_1()
# print(system_instruction_1)
model = genai.GenerativeModel(model_name="gemini-1.5-pro-latest",
                            generation_config=generation_config,
                            system_instruction=system_instruction_1,
                            safety_settings=safety_settings)

# %%
# %%time

random.shuffle(self.prompt_parts)
response = model.generate_content(self.prompt_parts,
                                request_options={"timeout": 1000})
minutes_text = str(response.text)
print(minutes_text)
# Out:
# ## Gemini Candlestick Investment Fund Meeting Minutes
#
# **Date:** May 24, 2024
# **Time:** 00:00 - 01:30
# **Location:** Google Meet
#
# **1. Broad Market Analysis:**
#
# The Board of Directors convened to assess market conditions and potential investment opportunities, utilizing technical analysis and expert opinions across various sectors:
#
# * **Real Estate (Bearish):** Concerns were raised about the real estate sector. John Bollinger noted that **Simon Property Group Inc. (SPG)** is displaying a tightening of Bollinger Bands, often a precursor to a breakout or breakdown. Combined with the bearish engulfing pattern observed by Munehisa Homma, the Board leans towards a potential downturn in this sector.
# ...

# %%
# %%time

minutes_html = str(genai.GenerativeModel(model_name="gemini-1.5-flash-latest",
                generation_config=generation_config,
                system_instruction="Your role is to translate the user's meeting minutes into HTML format.",
                safety_settings=safety_settings).generate_content(minutes_text).text)
# Out:
# CPU times: user 23.8 ms, sys: 18.1 ms, total: 41.9 ms
# Wall time: 23.3 s

# %%
# print(minutes_html)

minutes_html = minutes_html.replace('```html','')
minutes_html = minutes_html.replace('```','')

# %%
pdfkit.from_string(minutes_html, 'data/pdf/minutes.pdf')
# Out:
# True

# %%
# %%time

summary_text = str(genai.GenerativeModel(model_name="gemini-1.5-pro-latest",
                            generation_config=generation_config,
                            system_instruction=self.get_system_instructions_2(),
                            safety_settings=safety_settings).generate_content(minutes_text).text)

# %%
summary_html = str(genai.GenerativeModel(model_name="gemini-1.5-flash-latest",
                            generation_config=generation_config,
                            system_instruction="Your role is to translate the user's meeting minutes into HTML format.",
                            safety_settings=safety_settings).generate_content(summary_text).text)

# %%
summary_html = summary_html.replace('```html','')
summary_html = summary_html.replace('```','')
pdfkit.from_string(summary_html, 'data/pdf/summary.pdf')
# Out:
# True

# %%
# print(summary_text)

# %%
# %%time

minutes_html = genai.GenerativeModel(model_name="gemini-1.5-flash-latest",
                generation_config=generation_config,
                system_instruction=self.get_system_instructions_4(),
                safety_settings=safety_settings).generate_content(minutes_text).text

# %%
summary_text = genai.GenerativeModel(model_name="gemini-1.5-pro-latest",
                            generation_config=generation_config,
                            system_instruction=self.get_system_instructions_2(),
                            safety_settings=safety_settings).generate_content(generative_text).text

# %%
print(summary_text)
# Out:
# ## Gemini Candlestick Investment Fund Meeting Summary - May 24, 2024
#
# **1. Concise Summary:**
#
# The Gemini Candlestick Investment Fund Board maintains a cautiously bullish market outlook, acknowledging growth potential in specific sectors while remaining vigilant of inflation and rising interest rate risks. The fund will retain its core holdings in strong performers like MSFT, AAPL, and JNJ.  The strategy focuses on increasing exposure to Information Technology and Renewable Energy (targeting NVDA and NEE), driven by strong earnings and favorable long-term trends.  The Board will leverage technical analysis to capitalize on opportunistic trades, such as potential plays in WFC and XOM.  Risk management through diversification, stop-loss orders, and position limits remains a high priority.
#
# **2. Sector Analysis:**
#
# * **Strong Sectors:**
# ...

# %%
for _ in range(6):
    try:
        interest_ticker_list = genai.GenerativeModel(model_name="gemini-1.5-flash-latest",
                                    generation_config=generation_config,
                                    system_instruction="""Your role is to extract ticker symbols of "**4. Ticker Symbols of Interest:**" into JSON object format.""",
                                    safety_settings=safety_settings).generate_content(generative_text).text
        key = list(self.extract_json(interest_ticker_list)[0].keys())[0]
        interest_ticker_list = self.extract_json(interest_ticker_list)[0][key]
        match_no = 0
        for each_ticket in ticket_list:
            if each_ticket in self.ticker_list:
                match_no = match_no + 1
        if match_no == len(ticket_list):
            break
    except:
        pass

# %%
from img2pdf import convert

# Convert the PNG files to PDF
png_files = [f'data/png/{each}.png' for each in interest_ticker_list]
with open("data/pdf/png.pdf", "wb") as pdf_file:
    pdf_bytes = convert(png_files)
    pdf_file.write(pdf_bytes)
# Out:
# Image contains an alpha channel. Computing a separate soft mask (/SMask) image to store transparency in PDF.
# Image contains an alpha channel. Computing a separate soft mask (/SMask) image to store transparency in PDF.
# Image contains an alpha channel. Computing a separate soft mask (/SMask) image to store transparency in PDF.
# Image contains an alpha channel. Computing a separate soft mask (/SMask) image to store transparency in PDF.
# 4632402

# %%
# Out:
# ['AAPL',
#  'ABBV',
#  'ABNB',
#  'ABT',
#  'ACN',
#  'ADBE',
#  'ADI',
#  'ADP',
#  'ADSK',
#  'AEP',
#  'AIG',
#  'ALGN',
#  'AMAT',
#  'AMD',
#  'AMGN',
#  'AMT',
#  'AMZN',
#  'ANSS',
#  'ASML',
#  'AVGO',
#  'AXP',
#  'AZN',
#  'BA',
#  'BAC',
#  'BIDU',
#  'BIIB',
#  'BK',
#  'BKNG',
#  'BLK',
#  'BMY',
#  'BRK-B',
#  'C',
#  'CAT',
#  'CDNS',
#  'CHTR',
#  'CL',
#  'CMCSA',
#  'COF',
#  'COP',
#  'COST',
#  'CPRT',
#  'CRM',
#  'CRWD',
#  'CSCO',
#  'CSX',
#  'CTAS',
#  'CTSH',
#  'CVS',
#  'CVX',
#  'DDOG',
#  'DHR',
#  'DIS',
#  'DLTR',
#  'DOCU',
#  'DOW',
#  'DUK',
#  'DXCM',
#  'EA',
#  'EBAY',
#  'EMR',
#  'EXC',
#  'F',
#  'FAST',
#  'FDX',
#  'FTNT',
#  'GD',
#  'GE',
#  'GILD',
#  'GM',
#  'GOOGL',
#  'GS',
#  'HD',
#  'HON',
#  'IBM',
#  'IDXX',
#  'ILMN',
#  'INTC',
#  'INTU',
#  'ISRG',
#  'JD',
#  'JNJ',
#  'JPM',
#  'KDP',
#  'KHC',
#  'KLAC',
#  'KO',
#  'LCID',
#  'LIN',
#  'LLY',
#  'LMT',
#  'LOW',
#  'LRCX',
#  'LULU',
#  'MA',
#  'MAR',
#  'MCD',
# ...

# %%
ticket_list
# Out:
# ['WFC', 'XOM', 'NVDA', 'HON']

# %%
# %%time

random.shuffle(self.prompt_parts)
response = model.generate_content(self.prompt_parts,
                                request_options={"timeout": 1000})
generative_text = str(response.text)
print(generative_text)
# Out:
# ## Gemini Candlestick Investment Fund Meeting Minutes
#
# **Date:** May 24, 2024
# **Time:** 00:00 - 01:30
# **Location:** Google Meet
#
# **1. Broad Market Analysis:**
#
# The Board convened to assess the current market landscape, focusing on technical indicators and trends across key sectors. The following is a summary of their observations:
#
# * **Information Technology:** The sector is showing signs of strength, with several stocks exhibiting bullish signals. However, concerns remain regarding potential overvaluation in some areas. **Nvidia Corporation (NVDA)**'s impressive uptrend is a significant driver, but Marc Chaikin, analyzing the Chaikin Money Flow, expressed concerns about a potential divergence suggesting waning buying pressure.
#
# ...

# %%
# def get_system_instructions_2(self):
#     system_instructions = f"""
#     {self.get_judge_instructions()}
    
#     ## Gemini Candlestick Investment Fund Meeting Summary - {self.current_meeting_date}

#     You are provided with detailed minutes from the latest Gemini Candlestick Investment Fund meeting.  Your task is to analyze this information and create a concise and insightful summary for the fund's managers. 

#     **Meeting Minutes:** 
#     [Insert the transcript of the full meeting recorded in the user's initial input]

#     **Objective:**  Summarize the provided meeting minutes, focusing on key decisions, market observations, and interconnections between sectors. Extract impactful insights relevant to the Gemini Candlestick Investment Fund's investment strategy.

#     **Instructions:**

#     1. **Concise Summary:**  Provide a clear and concise summary of the meeting's key discussions and decisions. This should include:
#         * Overall market sentiment and the rationale behind it.
#         * The fund's investment strategy and its justification.
#         * Risk management measures being implemented. 

#     2. **Sector Analysis:**  Analyze the discussion around each sector. Highlight:
#         * The perceived strength or weakness of the sector.
#         * Key factors and technical indicators driving the assessment.
#         * Specific companies mentioned and the rationale for their inclusion.

#     3. **Interconnected Insights:**  Identify and elaborate on the key interconnections observed between different sectors. Explain how these connections influence the fund's decisions.

#     4. **Actionable Takeaways:**  Based on the meeting discussions, extract actionable takeaways and insights relevant to the fund's investment strategy. This might include:
#         * Emerging investment opportunities.
#         * Potential risks to be aware of.
#         * Key trends influencing market dynamics.

#     5. **Language:**  Use clear, professional, and business-oriented language. Avoid technical jargon where possible and explain any necessary technical terms in a way that is easy to understand.

#     **Example Insights:**

#     * "The meeting highlighted a growing divergence between traditional utilities and renewable energy, indicating a potential shift in investor sentiment towards sustainable investments."
#     * "The strong performance of [INSERT_TICKET] suggests continued growth in the technology sector, potentially creating ripple effects in related industries like consumer electronics and e-commerce."
#     * "The fund's cautious optimism reflects a balanced approach, capitalizing on growth opportunities while acknowledging potential market risks." 
#     """
#     return system_instructions
# print(get_system_instructions_2(self))

# %%
# Gemini Candlestick Investment Fund Meeting Summary - May 20, 2024
# Overall Market Sentiment: The Board expressed cautious optimism about the market. While acknowledging the weakness in sectors like Real Estate and traditional Utilities, the Board sees strong momentum and growth potential in Information Technology, Consumer Discretionary, and Renewable Energy.

# Investment Strategy: The fund will adopt a balanced approach:

# Bullish: Targeting select stocks in Information Technology (e.g., NVDA, MSFT), Consumer Discretionary, and Renewable Energy (e.g., NEE).
# Neutral: Monitoring Health Care, Industrials, and Consumer Staples for emerging opportunities.
# Bearish: Implementing a strategic short strategy on specific stocks within Real Estate (e.g., SPG), Utilities, and Financials.
# Risk Management: The fund will implement stop-loss orders, diversification, hedging strategies, and position limits to mitigate potential losses.

# Sector Analysis:
# Strong Sectors:

# Information Technology: Driven by NVDA's strong momentum (Bollinger Band breakout) and MSFT's potential "squeeze" (narrowing Bollinger Bands, potential Elliott Wave 3).
# Renewable Energy: Supported by NEE's consistent accumulation (strong OBV), continued buying pressure (upper Bollinger Band), and the broader shift towards sustainable energy.
# Consumer Discretionary: Boosted by the strength of companies like AMZN, bouncing off key Fibonacci retracement levels. However, concerns remain regarding specific companies like MCD with bearish Chaikin Money Flow.
# Weak Sectors:

# Real Estate: Weighed down by SPG's downtrend (trading below lower Bollinger Band with expanding volume) and increased volatility (elevated ATR).
# Utilities: Facing challenges due to the shift towards renewables. DUK potentially in a corrective Elliott Wave, trading below the Ichimoku Cloud.
# Financials: Showing mixed signals with some stocks consolidating while others attempt to break resistance. Concerns remain regarding specific companies like WFC experiencing continued weakness (stochastic oscillator in oversold territory).
# Other Sectors:

# Health Care: Presenting a mixed picture, with some companies consolidating and others potentially finding support at Fibonacci levels.
# Industrials: Showing overall strength with companies like CAT breaking through resistance, but some companies lag, trading within the lower Bollinger Band.
# Consumer Staples: Displaying resilience with some companies trading near all-time highs, but potential reversals (bearish engulfing pattern in MDLZ) require careful monitoring.
# Materials: Characterized by mixed signals, with some companies breaking above the Ichimoku Cloud and others remaining range-bound.
# Interconnected Insights:
# Technology and Consumer Discretionary: The strength in NVDA (chip supplier) suggests continued demand in gaming and e-commerce, positively impacting companies like AMZN.
# Utilities and Renewable Energy: The relative weakness in traditional utilities compared to NEE's strength highlights the ongoing shift towards renewables, presenting both challenges and opportunities.
# Actionable Takeaways:
# Emerging Opportunities: Investigate long positions in NVDA, MSFT, and NEE, given their strong technical setups and favorable sector dynamics.
# Potential Risks: Monitor Real Estate and traditional Utilities closely due to their weak technical indicators and unfavorable sector outlook. Be cautious of potential reversals in Consumer Staples, particularly MDLZ.
# Key Trends: The shift towards renewable energy and the ongoing strength in technology are key trends shaping market dynamics and investment decisions.
# Next Steps: The fund's management team will conduct in-depth analysis of the highlighted ticker symbols (NVDA, MSFT, NEE, SPG, and MDLZ) to determine precise entry and exit points for trades. The Board will reconvene in one week to review the fund's position and adapt to evolving market dynamics.

# %%
def get_system_instructions_2(self):
    system_instructions = f"""
    {self.get_judge_instructions()}

    Your task is to translate and rewrite the user's meeting minutes, with a specific emphasis on the judging round mentioned above. It is crucial to employ professional and business-oriented language while incorporating critical analysis that highlights the interconnections among key sectors. The revised text should be easily understood by all individuals. Please provide links between sectors in the Broad Market Analysis, along with insightful observations. You should refrain from using technical indicator terms and instead substitute them with simplified business terminology to enhance clarity.
    """
    return system_instructions

# %%
print(get_system_instructions_2(self))

# %%
for each_prompt_part in tqdm(self.prompt_parts):
    genai.delete_file(each_prompt_part.name)

# %%
#     'Information Technology',
#     'Health Care',
#     'Consumer Discretionary',
#     'Communication Services',
#     'Industrials',
#     'Consumer Staples',
#     'Utilities',
#     'Renewable Energy',
#     'Real Estate',
#     'Materials',
#     'Financials'

# %%
self.company_ticker_list[0]

# %%
{self.company_ticker_list[0]}

# %%
# ', '.join(com_list)

# %%
# for each_ticker in self.nasdaq_100_tickers_list[30:]:
#     self.ticker = each_ticker
#     self.get_candlestick_image()

# %%
# self.nasdaq_100_tickers_list[30:]

# %%
# self.ticker = 'TSLA'
# %time self.get_candlestick_image()

# %%
# self.nasdaq_100_tickers_list

# %%
# self.get_depth(format = 'string', limit_no = 1000) 34k
# self.get_candlestick_json(tf = "30m") 23k
# 23000 * 10

# %%
# self.update_next_current_time_interval()
# wait_entry_sec = self.next_current_time_interval_df['next_entry_sec'].values[0]

# wait_entry_sec

# %%
# %time self.get_candlestick_image()

# %time self.get_depth_image()

# %%
# for each_freq_interval in ['1w', '3d', '1d', '12h', '8h', '6h', '4h', '2h', '1h', '30m']:
#     self.freq_interval = each_freq_interval
#     self.get_candlestick_image()

# %%
# %%time

# if self.model == 'gemini-1.5-pro-latest_vision':
#     print('vision')
#     generative_response, execution_time, result_dict = self.get_gemini_response_2()
    
# elif self.model == 'gemini-1.5-pro-latest':
#     print('OK !')
#     generative_response, execution_time, result_dict = self.get_gemini_response()

# print(generative_response)`

# %%
# 500 >> 16100
# 100 >> 3200
# 50 >> 1600
# 20 >> 640
# 10 >> 256
# 5 >> 128
16100 + 3200 + 1600 + 640 + 256 + 128

# %%
# 100 >> 3200
# 50 >> 1600
# 20 >> 640
# 10 >> 256
# 5 >> 128
3200 + 1600 + 640 + 256 + 128

# %%
(32000 - 5824) / 10

# %%
# import docker

# def get_container_memory_usage(container_id):
#     client = docker.from_env()
#     container = client.containers.get(container_id)
#     stats = container.stats(stream=False)
#     memory_stats = stats['memory_stats']
#     memory_usage = memory_stats['usage']
#     memory_usage_gb = memory_usage / (1024 * 1024 * 1024)  # Convert bytes to GB
#     return memory_usage_gb

# # Specify the container ID or name
# container_id = 'Container01'

# # Get the memory usage of the container
# memory_usage_gb = get_container_memory_usage(container_id)
# print(f"Container memory usage: {memory_usage_gb:.4f} GB")

# %%
system_instructions = """
You will receive user-input minutes of the board of directors meeting, and your primary role is to generate a JSON response. This JSON response is essential for completing the task effectively. It should be structured and formatted appropriately, providing all necessary information and data in a clear and concise manner. By fulfilling this responsibility diligently, you significantly contribute to the proper documentation and communication of the meeting's decisions.

**Your JSON Response Formatting:**
{       "type": "object",
"properties": {
    "analyzed_asset": {
    "type": "string"
    },
    "rationale_for_long_position": {
    "type": "string"
    },
    "rationale_for_short_position": {
    "type": "string"
    },
    "rationale_for_neutral_position": {
    "type": "string"
    },
    "analysis_overview": {
    "type": "string"
    },
    "meeting_consensus_action": {
    "type": "string",
    "enum": ["long", "short", "neutral"]
    }
},
"required": [
    "analyzed_asset",
    "rationale_for_long_position",
    "rationale_for_short_position",
    "rationale_for_neutral_position",
    "analysis_overview",
    "meeting_consensus_action"
]
}
"""

# %%
print(system_instructions)

# %%
import requests
import certifi

# Provide the CA bundle from certifi
response = requests.get("https://www.google.com", verify=certifi.where())

# %%
response.json
# Out:
# <bound method Response.json of <Response [200]>>

# %%
import telegram

BOT_TOKEN = '6634636445:AAE4FORei5yEjJmEZmEOHLrHQ4URFKB-yqI'
CHAT_ID = "-1002105947055"

bot = telegram.Bot(token=BOT_TOKEN)
bot.send_message(chat_id=CHAT_ID, text='Hello 1234 12312312312')
# Out:
# <coroutine object Bot.send_message at 0x7f82ea57fe40>

# %%
chat_id = '-4256435996'
message_text = 'Hello'

bot.send_message(chat_id=chat_id, text=message_text)

# %%
TOKEN = '6634636445:AAE4FORei5yEjJmEZmEOHLrHQ4URFKB-yqI'

url = f"https://api.telegram.org/bot{TOKEN}/getUpdates"

# %%
res = requests.get(url)

# %%
res.json()

# %%
import requests

BOT_TOKEN = '6634636445:AAE4FORei5yEjJmEZmEOHLrHQ4URFKB-yqI'
CHAT_ID = "-1002105947055"

def send_message(message):
    url = f"https://api.telegram.org/bot{BOT_TOKEN}/sendMessage"
    payload = {
        "chat_id": CHAT_ID,
        "text": message
    }
    requests.post(url, json=payload)

# Usage
send_message("Bot: Hello, this is a test message!6")

# %%
def send_photo(photo, caption=None):
    url = f"https://api.telegram.org/bot{BOT_TOKEN}/sendPhoto"
    payload = {
        "chat_id": CHAT_ID
    }
    
    if caption:
        payload["caption"] = caption
        
    files = {
        "photo": photo
    }
    
    requests.post(url, data=payload, files=files)

# Usage
with open("8h_candlestick_with_technical_indicators_chart.png", "rb") as f:
    photo = f.read()
    send_photo(photo, caption="This is a test image. 2")

# %%
# Replace with the path to your PDF file
PDF_FILE_PATH = "temp.pdf"

def send_pdf(chat_id, pdf_file_path, token, caption):
    url = f"https://api.telegram.org/bot{token}/sendDocument"
    files = {"document": open(pdf_file_path, "rb")}
    data = {"chat_id": chat_id, "caption": caption}
    response = requests.post(url, files=files, data=data)
    print(response.status_code)

# Add a caption to the PDF file
caption = "This is a caption for the PDF file."
send_pdf(CHAT_ID, PDF_FILE_PATH, BOT_TOKEN, caption)

# %%
def send_pdfs(chat_id, pdf_dir, token):
    url = f"https://api.telegram.org/bot{token}/sendDocument"
    pdf_files = [f for f in os.listdir(pdf_dir) if f.endswith('.pdf')]

    for pdf_file in pdf_files:
        pdf_file_path = os.path.join(pdf_dir, pdf_file)
        caption = f"Caption for {pdf_file}"
        files = {"document": open(pdf_file_path, "rb")}
        data = {"chat_id": chat_id, "caption": caption}
        response = requests.post(url, files=files, data=data)
        print(f"Sent {pdf_file}: {response.status_code}")

send_pdfs(CHAT_ID, 'pdfs', BOT_TOKEN)

# %%
def send_photos(chat_id, photo_dir, token):
    url = f"https://api.telegram.org/bot{token}/sendPhoto"
    photo_files = [f for f in os.listdir(photo_dir) if f.endswith(('.jpg', '.png', '.jpeg'))]

    for photo_file in photo_files:
        photo_file_path = os.path.join(photo_dir, photo_file)
        caption = f"Caption for {photo_file}"
        files = {"photo": open(photo_file_path, "rb")}
        data = {"chat_id": chat_id, "caption": caption}
        response = requests.post(url, files=files, data=data)
        print(f"Sent {photo_file}: {response.status_code}")

send_photos(CHAT_ID, 'photos', BOT_TOKEN)

# %%
# pip install requests_toolbelt

# %%
photo_paths = [
    'photos/1.png',
    'photos/2.png',
    'photos/3.png',
]

# %%
image_paths = [
    'photos/1.png',
    'photos/2.png',
    'photos/3.png',
]

# Replace with your bot token
bot_token = BOT_TOKEN

# Replace with your chat ID
chat_id = CHAT_ID

# %%
import requests
from PIL import Image
import io

# %%
# Open the images
images = [Image.open(path) for path in image_paths]

# Calculate the width and height of the merged image
widths, heights = zip(*(i.size for i in images))
total_width = sum(widths)
max_height = max(heights)

# Create a new image with the calculated size and paste the individual images
merged_image = Image.new('RGB', (total_width, max_height))
x_offset = 0
for image in images:
    merged_image.paste(image, (x_offset, 0))
    x_offset += image.size[0]

# Save the merged image to a BytesIO object
merged_image_bytes = io.BytesIO()
merged_image.save(merged_image_bytes, format='PNG')
merged_image_bytes.seek(0)

# Send the merged image to Telegram
url = f'https://api.telegram.org/bot{bot_token}/sendPhoto'
files = {'photo': merged_image_bytes}
data = {'chat_id': chat_id}
response = requests.post(url, data=data, files=files)
print(response.json())

# %%
media = []
for i, image_path in enumerate(image_paths):
    with open(image_path, 'rb') as f:
        files = {'photo': f}
        data = {'type': 'photo', 'media': f'attach://photo{i}'}
        media.append(data)

data = {'chat_id': chat_id, 'media': json.dumps(media)}
url = f'https://api.telegram.org/bot{bot_token}/sendMediaGroup'
response = requests.post(url, data=data, files={f'photo{i}': open(image_paths[i], 'rb') for i in range(len(image_paths))})
print(response.json())

# %%
# chat_id = '-4256435996'
chat_id = "-1002105947055"
bot_token = '6634636445:AAE4FORei5yEjJmEZmEOHLrHQ4URFKB-yqI'

media = []
for i, pdf_path in enumerate(pdf_paths):
    print(pdf_path)
    with open(pdf_path, 'rb') as f:
        files = {'document': f}
        data = {'type': 'document', 'media': f'attach://document{i}'}
        media.append(data)

data = {'chat_id': chat_id, 'media': json.dumps(media)}
url = f'https://api.telegram.org/bot{bot_token}/sendMediaGroup'
response = requests.post(url, data=data, files={f'document{i}': open(pdf_paths[i], 'rb') for i in range(len(pdf_paths))})
print(response.json())
# Out:
# data/pdf/test.pdf
# {'ok': True, 'result': [{'message_id': 62, 'sender_chat': {'id': -1002105947055, 'title': 'Gemini Candlestick', 'username': 'geminicandlestick', 'type': 'channel'}, 'chat': {'id': -1002105947055, 'title': 'Gemini Candlestick', 'username': 'geminicandlestick', 'type': 'channel'}, 'date': 1716439721, 'document': {'file_name': 'test.pdf', 'mime_type': 'application/pdf', 'thumbnail': {'file_id': 'AAMCBQADHQR9hjOvAAM-Zk7KqXEfIHoPTpZD2luytzLZBGAAAogNAAI3C3FW-C6LnVKvj2MBAAdtAAM1BA', 'file_unique_id': 'AQADiA0AAjcLcVZy', 'file_size': 14750, 'width': 247, 'height': 320}, 'thumb': {'file_id': 'AAMCBQADHQR9hjOvAAM-Zk7KqXEfIHoPTpZD2luytzLZBGAAAogNAAI3C3FW-C6LnVKvj2MBAAdtAAM1BA', 'file_unique_id': 'AQADiA0AAjcLcVZy', 'file_size': 14750, 'width': 247, 'height': 320}, 'file_id': 'BQACAgUAAx0EfYYzrwADPmZOyqlxHyB6D06WQ9pbsrcy2QRgAAKIDQACNwtxVvgui51Sr49jNQQ', 'file_unique_id': 'AgADiA0AAjcLcVY', 'file_size': 287215}}]}

# %%
import nasdaqdatalink
from nasdaqdatalink import get_table

nasdaqdatalink.ApiConfig.api_key = '4hYxzJmidiq_8wvnJu6J'

df = nasdaqdatalink.get('NASDAQ/MSFT')

# df = nasdaqdatalink.get('NSE/OIL')

# %%
import nasdaqdatalink

# Set the API key
nasdaqdatalink.ApiConfig.api_key = '4hYxzJmidiq_8wvnJu6J'

# Get the data for Microsoft (MSFT) from the Nasdaq Data Link
df = nasdaqdatalink.get("NASDAQOMX/NDX", start_date = '2021-07-22')

# Print the DataFrame to check the fetched data
print(df.head())

# %%
df.tail()

# %%
# Get a list of all available symbols
symbols = get_table("SHARADAR/TICKERS")

# Filter the DataFrame to get NASDAQ-listed symbols
nasdaq_symbols = symbols[symbols["exchange"] == "NASDAQ"]

# Print the NASDAQ symbols
# print(nasdaq_symbols)

# %%
nasdaq_symbols.columns

# %%
nasdaq_symbols.iloc[0]

# %%
nasdaq_symbols['ticker'].value_counts()

# %%
quandl.get('CMHC/HPPU50_BC', authoken= api_key)

# %%
# pip install polygon-api-client

from polygon import RESTClient

key = "Vlf0w6Ve709H5bcBfgGxrLyg19ZXplXk"
client = RESTClient(key)

# %%
# Define the ticker symbol and the desired date range
ticker = "MSFT"
from_date = "2023-05-01"
to_date = "2023-05-15"

# Fetch the OHLCV data
resp = client.get_daily_open_close_agg(ticker, date = from_date, adjusted = True)

# %%
str(resp)

# %%
# import yfinance as yf

# msft = yf.Ticker("MSFT")

# # get all stock info
# msft.info

# # get historical market data
# hist = msft.history(period="1mo", limit = 10)

# %%
self.nasdaq_100_df = pd.read_csv('data/csv/nasdaq100.csv')
self.nasdaq_100_tickers_list = list(self.nasdaq_100_df['Ticker'].values)
self.ticker_company_dict = dict(zip(self.nasdaq_100_df['Ticker'], self.nasdaq_100_df['Company']))
self.ticker_sector_dict_1 = dict(zip(self.nasdaq_100_df['Ticker'], self.nasdaq_100_df['GISC Sector']))
self.ticker_sector_dict_2 = dict(zip(self.nasdaq_100_df['Ticker'], self.nasdaq_100_df['GISC Sub-Industry']))

# %%
# for each in nasdaq_info_df['Company'].values:
#     print(each)
#     print()

# %%
# Define the ticker list
import pandas as pd
import yfinance as yf

nasdaq_df = yf.download(nasdaq_100_tickers_list, period='168d', interval="1d")
date_list = [str(each)[:10] for each in list(nasdaq_df['Close'].index)]

# %%
# help(yf.utils)

# %%
# help(client.get_grouped_daily_aggs)

# %%
# help(client)

# %%
pdf_text = """
## The World's Largest Gold Emporium Board Meeting Minutes - May 16, 2024

**Location:** Bang Khun Phrom Palace (วังบางขุนพรม), Bangkok, Thailand

**Time:** 00:00 - 00:30

**Attendees:**

1. พระสยามเทวาธิราช (Phra Siam Devadhiraj), Chairman
2. Ken Griffin 
3. Munehisa Homma 
4. John Bollinger 
5. Leonardo Pisano Fibonacci 
6. Ralph Nelson Elliott 
7. Goichi Hosoda 
8. Joseph Granville 
9. Gerald Appel 
10. J. Welles Wilder 
11. George Lane 
12. Marc Chaikin 

**Secretary:** Governor of the Bank of Thailand

**Topic:** Assessing the anticipated movement of BTC in the upcoming 8 hours and determining a consensus position (long, short, or neutral).

**Data Presented:**

* Current BTCUSDT Market Depth (Top 5, 10, 20, 50, 100, 500, and 1000 bids and asks from the order book)
* BTCUSDT Candlestick Charts (30-minute, 1-hour, 2-hour, 4-hour, 6-hour, 8-hour, 12-hour, 1-day, 3-day, and 1-week timeframes)
* Technical Indicators:
    * Volume
    * RSI
    * MACD
    * Bollinger Bands
    * Fibonacci Retracement
    * Ichimoku Cloud
    * Stochastic Oscillator
    * Chaikin Money Flow
    * On-Balance Volume
    * Average True Range 

**Discussion:**

* **Ken Griffin:** Observing the market depth, there is considerable buying pressure at lower price levels, suggesting potential support for upward movement.
* **Munehisa Homma:** Candlestick patterns across multiple timeframes indicate a recent bullish reversal, further strengthening the case for an upward trajectory.
* **John Bollinger:** Bollinger Bands show price approaching the upper band, potentially signaling an overbought condition and a possible short-term retracement. However, continued momentum could result in a breakout above the upper band, indicating further upward movement.
* **Leonardo Pisano Fibonacci:** Fibonacci retracement levels highlight potential support and resistance zones. A break above the 0.618 level would suggest further bullish momentum.
* **Ralph Nelson Elliott:** Elliott Wave analysis indicates a potential wave 3 impulse wave forming, characteristic of strong upward price movements.
* **Goichi Hosoda:** Ichimoku Cloud analysis confirms the bullish trend, with price trading above the cloud and the future cloud projecting upward movement.
* **Joseph Granville:** Volume analysis reveals increasing buying volume, supporting the bullish thesis. On Balance Volume (OBV) also reflects positive buying pressure, confirming the bullish outlook.
* **Gerald Appel:** MACD indicator suggests growing bullish momentum, with the MACD line crossing above the signal line.
* **J. Welles Wilder:** RSI indicator shows a high reading, approaching overbought territory, potentially suggesting a short-term retracement. However, sustained momentum could lead to a continued upward trend. ATR indicates increasing volatility, which could fuel further price swings.
* **George Lane:** Stochastic Oscillator indicates an overbought condition, potentially signaling a short-term correction. However, a continued upward trend remains possible.
* **Marc Chaikin:** Chaikin Money Flow (CMF) signals strong buying pressure, reinforcing the bullish case.

**Consensus:**

Following a thorough analysis of the data and a comprehensive discussion, the Board reached a majority consensus favoring a **long position** on BTC in the upcoming 8 hours. 

* The confluence of multiple bullish signals from various technical indicators suggests a high probability of upward price movement. 
* However, the Board acknowledges the potential for short-term retracements due to overbought conditions indicated by some indicators. 

**Action:**

The Emporium will take a long position in BTC, while diligently monitoring market conditions for potential short-term adjustments.

**Approved by:** พระสยามเทวาธิราช (Phra Siam Devadhiraj), Chairman
"""

# %%
html_text = """
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>The World's Largest Gold Emporium Board Meeting Minutes</title>
    <style>
        body {
            font-family: sans-serif;
        }
        table {
            border-collapse: collapse;
            width: 100%;
        }
        th, td {
            text-align: left;
            padding: 8px;
            border: 1px solid black;
        }
        .meeting-details {
            margin-bottom: 20px;
        }
        .discussion {
            margin-bottom: 20px;
        }
    </style>
</head>
<body>
    <h1>The World's Largest Gold Emporium Board Meeting Minutes</h1>
    <div class="meeting-details">
        <h2>Meeting Details</h2>
        <table>
            <tr>
                <th>Location</th>
                <td>Bang Khun Phrom Palace (วังบางขุนพรม), Bangkok, Thailand</td>
            </tr>
            <tr>
                <th>Time</th>
                <td>00:00 - 00:30</td>
            </tr>
        </table>
    </div>

    <div>
        <h2>Attendees</h2>
        <ol>
            <li>พระสยามเทวาธิราช (Phra Siam Devadhiraj), Chairman</li>
            <li>Ken Griffin</li>
            <li>Munehisa Homma</li>
            <li>John Bollinger</li>
            <li>Leonardo Pisano Fibonacci</li>
            <li>Ralph Nelson Elliott</li>
            <li>Goichi Hosoda</li>
            <li>Joseph Granville</li>
            <li>Gerald Appel</li>
            <li>J. Welles Wilder</li>
            <li>George Lane</li>
            <li>Marc Chaikin</li>
        </ol>
    </div>

    <div>
        <h2>Secretary</h2>
        <p>Governor of the Bank of Thailand</p>
    </div>

    <div>
        <h2>Topic</h2>
        <p>Assessing the anticipated movement of BTC in the upcoming 8 hours and determining a consensus position (long, short, or neutral).</p>
    </div>

    <div>
        <h2>Data Presented</h2>
        <ul>
            <li>Current BTCUSDT Market Depth (Top 5, 10, 20, 50, 100, 500, and 1000 bids and asks from the order book)</li>
            <li>BTCUSDT Candlestick Charts (30-minute, 1-hour, 2-hour, 4-hour, 6-hour, 8-hour, 12-hour, 1-day, 3-day, and 1-week timeframes)</li>
            <li>Technical Indicators:</li>
            <ul>
                <li>Volume</li>
                <li>RSI</li>
                <li>MACD</li>
                <li>Bollinger Bands</li>
                <li>Fibonacci Retracement</li>
                <li>Ichimoku Cloud</li>
                <li>Stochastic Oscillator</li>
                <li>Chaikin Money Flow</li>
                <li>On-Balance Volume</li>
                <li>Average True Range</li>
            </ul>
        </ul>
    </div>

    <div class="discussion">
        <h2>Discussion</h2>
        <ul>
            <li><strong>Ken Griffin:</strong> Observing the market depth, there is considerable buying pressure at lower price levels, suggesting potential support for upward movement.</li>
            <li><strong>Munehisa Homma:</strong> Candlestick patterns across multiple timeframes indicate a recent bullish reversal, further strengthening the case for an upward trajectory.</li>
            <li><strong>John Bollinger:</strong> Bollinger Bands show price approaching the upper band, potentially signaling an overbought condition and a possible short-term retracement. However, continued momentum could result in a breakout above the upper band, indicating further upward movement.</li>
            <li><strong>Leonardo Pisano Fibonacci:</strong> Fibonacci retracement levels highlight potential support and resistance zones. A break above the 0.618 level would suggest further bullish momentum.</li>
            <li><strong>Ralph Nelson Elliott:</strong> Elliott Wave analysis indicates a potential wave 3 impulse wave forming, characteristic of strong upward price movements.</li>
            <li><strong>Goichi Hosoda:</strong> Ichimoku Cloud analysis confirms the bullish trend, with price trading above the cloud and the future cloud projecting upward movement.</li>
            <li><strong>Joseph Granville:</strong> Volume analysis reveals increasing buying volume, supporting the bullish thesis. On Balance Volume (OBV) also reflects positive buying pressure, confirming the bullish outlook.</li>
            <li><strong>Gerald Appel:</strong> MACD indicator suggests growing bullish momentum, with the MACD line crossing above the signal line.</li>
            <li><strong>J. Welles Wilder:</strong> RSI indicator shows a high reading, approaching overbought territory, potentially suggesting a short-term retracement. However, sustained momentum could lead to a continued upward trend. ATR indicates increasing volatility, which could fuel further price swings.</li>
            <li><strong>George Lane:</strong> Stochastic Oscillator indicates an overbought condition, potentially signaling a short-term correction. However, a continued upward trend remains possible.</li>
            <li><strong>Marc Chaikin:</strong> Chaikin Money Flow (CMF) signals strong buying pressure, reinforcing the bullish case.</li>
        </ul>
    </div>

    <div>
        <h2>Consensus</h2>
        <p>Following a thorough analysis of the data and a comprehensive discussion, the Board reached a majority consensus favoring a <strong>long position</strong> on BTC in the upcoming 8 hours.</p>
        <ul>
            <li>The confluence of multiple bullish signals from various technical indicators suggests a high probability of upward price movement.</li>
            <li>However, the Board acknowledges the potential for short-term retracements due to overbought conditions indicated by some indicators.</li>
        </ul>
    </div>

    <div>
        <h2>Action</h2>
        <p>The Emporium will take a long position in BTC, while diligently monitoring market conditions for potential short-term adjustments.</p>
    </div>

    <div>
        <h2>Approved by</h2>
        <p>พระสยามเทวาธิราช (Phra Siam Devadhiraj), Chairman</p>
    </div>
</body>
</html>
"""

# %%
# Your role is to translate this minute of the meeting into HTML format.
# https://github.com/JazzCore/python-pdfkit/wiki/Installing-wkhtmltopdf

import pdfkit

# pdfkit_config = pdfkit.configuration(wkhtmltopdf='/path/to/wkhtmltopdf')
pdfkit.from_string(html_text, 'output.pdf')
# Out:
# True

# %%
from img2pdf import convert
from PIL import Image
import os

print('OK !')

# %%
from img2pdf import convert
import os

def convert_png_to_pdf(png_dir, pdf_path):
    # Get a list of all PNG files in the directory
    png_files = [os.path.join(png_dir, file) for file in os.listdir(png_dir) if file.endswith('.png')]

    # Convert the PNG files to PDF
    with open(pdf_path, "wb") as pdf_file:
        pdf_bytes = convert(png_files)
        pdf_file.write(pdf_bytes)

    print(f"PDF file created: {pdf_path}")
    
convert_png_to_pdf('png', 'png.pdf')

# %%
from pdf2image import convert_from_path
from PIL import Image

def make_pdf_uncroppable(input_pdf_path, output_pdf_path):
    """Converts a PDF to a sequence of images, creating an 'uncroppable' PDF.

    Args:
        input_pdf_path (str): The path to the input PDF file.
        output_pdf_path (str): The path where the output PDF will be saved.
    """

    images = convert_from_path(input_pdf_path)

    # If your PDF has multiple pages:
    if len(images) > 1:
        images[0].save(
            output_pdf_path,
            "PDF",
            resolution=100.0,
            save_all=True,
            append_images=images[1:],
        )
    else:
        images[0].save(output_pdf_path, "PDF", resolution=100.0)

# Example usage:
input_pdf = "output.pdf"
output_pdf = "output_2.pdf"
make_pdf_uncroppable(input_pdf, output_pdf)

# %%
from PyPDF2 import PdfMerger

def merge_pdfs(paths, output_filename):

    merger = PdfMerger()

    for path in paths:
        merger.append(path)

    merger.write(output_filename)
    merger.close()

# Example usage
pdf_paths = ["output_2.pdf", "png.pdf"]
output_file = "merged.pdf"
merge_pdfs(pdf_paths, output_file)

# %%
import time

interval = 4  # Target interval in seconds
next_start_time = time.time()  # Initialize the start time

while True:
    # Perform your operation (taking less than a second)
    # Replace the following line with your actual operation
    i = 0  # Example operation

    # Calculate the next start time
    next_start_time += interval
    
    # Sleep until the next start time
    current_time = time.time()
    sleep_time = next_start_time - current_time
    if sleep_time > 0:
        time.sleep(sleep_time)

# %%
interval = 4  # Target interval in seconds
next_start_time = time.time()  # Initialize the start time

# while

# Perform your operation (taking less than a second)
# Replace the following line with your actual operation
time.sleep(0.5) # Example operation

# Calculate the next start time
next_start_time += interval

# Sleep until the next start time
current_time = time.time()
sleep_time = next_start_time - current_time
if sleep_time > 0:
    time.sleep(sleep_time)
