# %%
#Default
import pandas as pd
pd.options.display.float_format = '{:,}'.format
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
def reset(df):
    cols = df.columns
    return df.reset_index()[cols]
def print_counts(df):
    cols = df.columns
    for each in cols:
        print(each)
        print(df[each].value_counts())
        print('______________________________________')
# ~
#Default Ending

from plotly.subplots import make_subplots
from plotly.graph_objects import Scatter
from plotly.io import to_image
from itertools import accumulate 

import datetime
import time

from tqdm import tqdm
import numpy as np


import json

# from autotrade import autotrade
import google.generativeai as genai


def human_format(num):
    magnitude = 0
    while abs(num) >= 1000:
        magnitude += 1
        num /= 1000.0
    # add more suffixes if you need them
    return '%.0f%s' % (num, ['', 'K', 'M', 'G', 'T', 'P'][magnitude])

def add(a, b):
    return a + b

def get_color_list(values):
    # Define dark and light shades of green and red
    dark_green = '#26A69A'
    light_green = '#B2DFDB'
    light_red = '#FFCDD2'
    dark_red = '#FF5252'
    colors = []
    previous_value = values[0]
    for value in values:
        if value < 0:
            if value < previous_value:
                colors.append(dark_red)
            else:
                colors.append(light_red)
        elif value > 0:
            if value > previous_value:
                colors.append(dark_green)
            else:
                colors.append(light_green)
        else:
            colors.append(light_green)  # Adjust for zero values as needed
        previous_value = value
    return colors

# Function to format y-axis labels
def millions_formatter(x, pos):
    num = x
    magnitude = 0
    while abs(num) >= 1000:
        magnitude += 1
        num /= 1000.0
    # add more suffixes if you need them
    return '%.0f%s' % (num, ['', 'K', 'M', 'G', 'T', 'P'][magnitude])
def comma_formatter(x, pos):
    return "{:,}".format(x)
def comma_formatter_2(x, pos):
    return "{:,.2f}".format(x)
def title_formatter(x):
    return "{:.2f}".format(x)

import talib
from plotly.tools import mpl_to_plotly
import matplotlib
matplotlib.use('Agg')

import matplotlib.pyplot as plt
plt.rc('figure', figsize = (15, 12), dpi = 300)
from mplfinance.original_flavor import candlestick_ohlc
import matplotlib.dates as mdates
from matplotlib.ticker import FuncFormatter
from matplotlib.lines import Line2D

from geminicandlestick import *

def get_date_month_text(date_str):
    date_obj = datetime.datetime.strptime(date_str, "%Y-%m-%d")
    return date_obj.strftime("%d %b")

# from IPython.display import display, HTML
# display(HTML("<style>.container { width:100% !important; }</style>"))

print('OK !')
# Out:
# /var/folders/v6/n3wvvznj569b16762k0t9ywc0000gn/T/ipykernel_60956/2191464957.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# OK !

# %%
if not os.path.exists('data/pdf'):
    os.makedirs('data/pdf')
if not os.path.exists('data/csv'):
    os.makedirs('data/csv')
if not os.path.exists('data/png'):
    os.makedirs('data/png')

# %%
self = GeminiCandlestick(gemini_key = "AIzaSyCY2krWzRCAMU9n4BP4KAeQgDeQ2cM9NgI",
                 BOT_TOKEN = '6634636445:AAE4FORei5yEjJmEZmEOHLrHQ4URFKB-yqI',
                 CHAT_ID = "-1002105947055",
                 freq_interval = '1d',
                )
# self.gemini_key = "AIzaSyCY2krWzRCAMU9n4BP4KAeQgDeQ2cM9NgI
# self.gemini_key = "AIzaSyDZKy-_yHEtMqmVF-62t7Q7n5r_Ca0HRCU"

# self.model = 'gemini-1.5-pro-latest'
# self.model = 'gemini-1.5-flash-latest'

# %%
self.prep_sp100_nasdaq100_dataset()
# Out:
# [*********************100%%**********************]  171 of 171 completed
#
# 4 Failed downloads:
# ['SPLK', 'RTN', 'ATVI', 'SGEN']: Exception('%ticker%: No data found, symbol may be delisted')
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 171/171 [00:03<00:00, 53.60it/s]

# %%
self.sp100_nasdaq100_df.shape
# Out:
# (166, 10)

# %%
self.generate_gemini_candlestick()
# Out:
#   0%|                                                                                                                                             | 0/166 [00:00<?, ?it/s]/Users/thanatchonchongmankhong/github/gemini-candlestick/geminicandlestick.py:1338: UserWarning:
#
# set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#
#   1%|▊                                                                                                                                    | 1/166 [00:17<48:47, 17.74s/it]/Users/thanatchonchongmankhong/github/gemini-candlestick/geminicandlestick.py:1338: UserWarning:
#
# set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#
#